# %% [markdown]
# ## **About Dataset**
# This dataset consist of data from Spotify's API on all albums listed on Spotify for the Rolling Stones. At first it may look like there are song duplicates but I checked and all song IDs are unique.
#
# *The columns in this* dataset are:
#
# **name** - the name of the song
#
# **album** - the name of the album
#
# **release_date** - the day month and year the album was released
#
# **track number** - the order the song appears on the album
#
# **id**- the Spotify id for the song
#
# **uri** - the Spotify uri for the song
#
# **acousticness** - A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# **danceability** - Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# **energy** - Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# **instrumentalness** - Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# **liveness** - Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# **loudness** - The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
#
# **speechiness** - detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# **tempo** - The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# **valence** - A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# **popularity** - the popularity of the song from 0 to 100
#
# **duration_ms** - The duration of the track in milliseconds.

# %%
# Análise Exploratória de Dados
import pandas as pd

# %%
df = pd.read_excel('/content/dataset_rolling_stones.xlsx')
df.head()
# Out:
#                           name               album release_date  track_number  \
# 0   Concert Intro Music - Live  Licked Live In NYC   2022-06-10             1
# 1   Street Fighting Man - Live  Licked Live In NYC   2022-06-10             2
# 2           Start Me Up - Live  Licked Live In NYC   2022-06-10             3
# 3  If You Can't Rock Me - Live  Licked Live In NYC   2022-06-10             4
# 4            Don’t Stop - Live  Licked Live In NYC   2022-06-10             5
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.0824         0.463   0.993          0.996000     0.932  -12913.0
# 1        0.4370         0.326   0.965          0.233000     0.961   -4803.0
# 2        0.4160         0.386   0.969          0.400000     0.956   -4936.0
# 3        0.5670         0.369   0.985          0.000107     0.895   -5535.0
# 4        0.4000         0.303   0.969          0.055900     0.966   -5098.0
#
# ...

# %%
# verificando as colunas e os tipos de dados na base
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              1610 non-null   object
#  1   album             1610 non-null   object
#  2   release_date      1610 non-null   datetime64[ns]
#  3   track_number      1610 non-null   int64
#  4   acousticness      1610 non-null   float64
#  5   danceability      1610 non-null   float64
#  6   energy            1610 non-null   float64
#  7   instrumentalness  1610 non-null   float64
#  8   liveness          1610 non-null   float64
#  9   loudness          1610 non-null   float64
#  10  speechiness       1610 non-null   float64
#  11  tempo             1610 non-null   float64
#  12  valence           1610 non-null   float64
#  13  popularity        1610 non-null   int64
#  14  duration_ms       1610 non-null   int64
# ...

# %%
# verificando a quantidade de linhas
df.shape
# Out:
# (1610, 15)

# %%
# iniciando as Análises -> queremos saber as datas de lançamentos de músicas - o ínicio e o fim do ano de lançamento dos álbuns.
print('Data Inicial: ', df['release_date'].min())
print('Data Final: ', df['release_date'].max())
# Out:
# Data Inicial:  1964-04-16 00:00:00
# Data Final:  2022-06-10 00:00:00

# %%
# se rodarmos o comando `isnull` sem utilizarmos a função de agregação `soma`, ele vai retornar o DF com dados booleanos - True e False
# True -> onde o dado é nulo | False -> onde o dado é não nulo
# mas essa forma não é muito prática para DF muito grande, já que teremos que olhar um por um
df.isnull()
# Out:
#        name  album  release_date  track_number  acousticness  danceability  \
# 0     False  False         False         False         False         False
# 1     False  False         False         False         False         False
# 2     False  False         False         False         False         False
# 3     False  False         False         False         False         False
# 4     False  False         False         False         False         False
# ...     ...    ...           ...           ...           ...           ...
# 1605  False  False         False         False         False         False
# 1606  False  False         False         False         False         False
# 1607  False  False         False         False         False         False
# 1608  False  False         False         False         False         False
# 1609  False  False         False         False         False         False
#
# ...

# %%
# uma coisa importante na Análise Exploratória de Dados é verificar se possuímos algum dado nulo no conjunto de
# dados que estamos trabalhando. Caso tenhamos algum dado nulo é preciso entender como tratar cada um deles individualmente
# uma forma de fazer essa verificação é somar todas as linhas que são nulas por coluna
df.isnull().sum()
# Out:
# name                0
# album               0
# release_date        0
# track_number        0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# liveness            0
# loudness            0
# speechiness         0
# tempo               0
# valence             0
# popularity          0
# duration_ms         0
# dtype: int64

# %%
# Uma outra verificação importante e essencial em nossos dados é verificar se temos dados duplicados, dependendo da nossa análises eles
# podem ser muito prejudiciais, já que assim, estariamos somando ou fazendo algum cálculo matemático 2 vezes.
# igual ao comando usado para verificar dados nulos, o comando para verificar dados duplicados retorna um booleano
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1605    False
# 1606    False
# 1607    False
# 1608    False
# 1609    False
# Length: 1610, dtype: bool

# %%
# rodando o comando abaixo, percebemos que temos 6 dados duplicados.
df.duplicated().sum()
# Out:
# 6

# %%
# verificando quais são os dados duplicados com um filtro
# ao rodar o comando abaixo, podemos verificar que o álbum é que está duplicado, não as linhas
# portanto não devemos mexer nesses dados
df[df.duplicated()]
# Out:
#                         name                        album release_date  \
# 928  Some Girls - Remastered  Some Girls (Deluxe Version)   1978-06-09
# 929        Lies - Remastered  Some Girls (Deluxe Version)   1978-06-09
# 935                 Claudine  Some Girls (Deluxe Version)   1978-06-09
# 939           No Spare Parts  Some Girls (Deluxe Version)   1978-06-09
# 940      Don't Be A Stranger  Some Girls (Deluxe Version)   1978-06-09
# 946             Petrol Blues  Some Girls (Deluxe Version)   1978-06-09
#
#      track_number  acousticness  danceability  energy  instrumentalness  \
# 928             4        0.5270         0.474   0.938          0.520000
# 929             5        0.4370         0.382   0.997          0.950000
# 935             1        0.0144         0.439   0.977          0.022100
# 939             5        0.2400         0.594   0.762          0.000015
# 940             6        0.0610         0.720   0.867          0.029700
# ...

# %%
# Início da Análise Exploratória dos Dados
# Primeiro passo é fazer uma Estatística Descritiva dos dados
# Analisando informações básicas de matemáticas, como média, valor mínimo e máximo, desvio padrão e quartil (que representa uma porcentagem de amostra dos dados).
df.describe()
# Out:
#                         release_date  track_number  acousticness  \
# count                           1610   1610.000000   1610.000000
# mean   1992-04-23 12:57:14.534161536      8.613665      0.250475
# min              1964-04-16 00:00:00      1.000000      0.000009
# 25%              1970-09-04 00:00:00      4.000000      0.058350
# 50%              1986-03-24 00:00:00      7.000000      0.183000
# 75%              2017-12-01 00:00:00     11.000000      0.403750
# max              2022-06-10 00:00:00     47.000000      0.994000
# std                              NaN      6.560220      0.227397
#
#        danceability       energy  instrumentalness    liveness      loudness  \
# count   1610.000000  1610.000000       1610.000000  1610.00000   1610.000000
# mean       0.468860     0.792352          0.164170     0.49173  -6406.640075
# min        0.104000     0.141000          0.000000     0.02190 -24408.000000
# ...

# %%
# se quisermos fazer o `describe` apenas dos dados numéricos, basta informar isso no parâmetro do DF
df.select_dtypes(include='number').describe()
# Out:
#        track_number  acousticness  danceability       energy  \
# count   1610.000000   1610.000000   1610.000000  1610.000000
# mean       8.613665      0.250475      0.468860     0.792352
# std        6.560220      0.227397      0.141775     0.179886
# min        1.000000      0.000009      0.104000     0.141000
# 25%        4.000000      0.058350      0.362250     0.674000
# 50%        7.000000      0.183000      0.458000     0.848500
# 75%       11.000000      0.403750      0.578000     0.945000
# max       47.000000      0.994000      0.887000     0.999000
#
#        instrumentalness    liveness      loudness  speechiness          tempo  \
# count       1610.000000  1610.00000   1610.000000  1610.000000    1610.000000
# mean           0.164170     0.49173  -6406.640075     0.069512  114078.725261
# std            0.276249     0.34910   3474.285941     0.051631   46196.602233
# min            0.000000     0.02190 -24408.000000     0.023200      65.990000
# ...

# %% [markdown]
# Para converter milissegundos em minutos, você pode usar a seguinte fórmula:
#
#
# $$Minutos = \frac{Milissegundos}{1000 * 60}$$
#
#  Passos:
# 1. Divida o número de milissegundos por 1000 para convertê-los em segundos.
# 2. Divida o resultado por 60 para obter o valor em minutos.
#
# Exemplo:
# Se você tem **120.000 milissegundos**:
#
# $$Minutos = \frac{120.000}{1000 \times 60} = \frac{120.000}{60.000} = 2 minutos$$

# %%
# a coluna duration_ms traz o tempo de duração de cada faixa em milissegundos
# vamos transformar esses dados para minutos, para melhor avaliá-los
# para transformar, vamos criar uma nova coluna
# é possível, também, ao invés de criar uma coluna nova, apenas substituir a existente, basta chamar o mesmo nome antes do sinal de =
df['duracao_minutos'] = df['duration_ms'] / 60000
df.head()
# Out:
#                           name               album release_date  track_number  \
# 0   Concert Intro Music - Live  Licked Live In NYC   2022-06-10             1
# 1   Street Fighting Man - Live  Licked Live In NYC   2022-06-10             2
# 2           Start Me Up - Live  Licked Live In NYC   2022-06-10             3
# 3  If You Can't Rock Me - Live  Licked Live In NYC   2022-06-10             4
# 4            Don’t Stop - Live  Licked Live In NYC   2022-06-10             5
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.0824         0.463   0.993          0.996000     0.932  -12913.0
# 1        0.4370         0.326   0.965          0.233000     0.961   -4803.0
# 2        0.4160         0.386   0.969          0.400000     0.956   -4936.0
# 3        0.5670         0.369   0.985          0.000107     0.895   -5535.0
# 4        0.4000         0.303   0.969          0.055900     0.966   -5098.0
#
# ...

# %%
# de curiosidade, vamos criar, também, a coluna de tempo em segundos
# para passarmos de minutos para segundos, basta multiplicar por 60
df['duracao_segundos'] = df['duracao_minutos'] * 60
df.head()
# Out:
#                           name               album release_date  track_number  \
# 0   Concert Intro Music - Live  Licked Live In NYC   2022-06-10             1
# 1   Street Fighting Man - Live  Licked Live In NYC   2022-06-10             2
# 2           Start Me Up - Live  Licked Live In NYC   2022-06-10             3
# 3  If You Can't Rock Me - Live  Licked Live In NYC   2022-06-10             4
# 4            Don’t Stop - Live  Licked Live In NYC   2022-06-10             5
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.0824         0.463   0.993          0.996000     0.932  -12913.0
# 1        0.4370         0.326   0.965          0.233000     0.961   -4803.0
# 2        0.4160         0.386   0.969          0.400000     0.956   -4936.0
# 3        0.5670         0.369   0.985          0.000107     0.895   -5535.0
# 4        0.4000         0.303   0.969          0.055900     0.966   -5098.0
#
# ...

# %%
df.describe()
# Out:
#                         release_date  track_number  acousticness  \
# count                           1610   1610.000000   1610.000000
# mean   1992-04-23 12:57:14.534161536      8.613665      0.250475
# min              1964-04-16 00:00:00      1.000000      0.000009
# 25%              1970-09-04 00:00:00      4.000000      0.058350
# 50%              1986-03-24 00:00:00      7.000000      0.183000
# 75%              2017-12-01 00:00:00     11.000000      0.403750
# max              2022-06-10 00:00:00     47.000000      0.994000
# std                              NaN      6.560220      0.227397
#
#        danceability       energy  instrumentalness    liveness      loudness  \
# count   1610.000000  1610.000000       1610.000000  1610.00000   1610.000000
# mean       0.468860     0.792352          0.164170     0.49173  -6406.640075
# min        0.104000     0.141000          0.000000     0.02190 -24408.000000
# ...

# %%
# agrupando dados pelos álbuns e tirando a média de tempo de cada álbum
df.groupby("album")['duracao_minutos'].mean()
# Out:
# album
# 12 X 5                              2.682068
# 12 x 5                              2.682772
# A Bigger Bang (2009 Re-Mastered)    4.016356
# A Bigger Bang (Live)                5.176630
# Aftermath                           3.899185
#                                       ...
# Undercover                          4.492750
# Undercover (2009 Re-Mastered)       4.497595
# Voodoo Lounge (Remastered 2009)     4.118779
# Voodoo Lounge Uncut (Live)          5.248507
# got LIVE if you want it!            2.762532
# Name: duracao_minutos, Length: 90, dtype: float64

# %%
# visualizando os dados
import matplotlib.pyplot as plt

# %%
# vamos construir um gráfico de barras de forma ordenada - maior para a menor média
# se o comando ficar muito grande, como o comando abaixo, podemos quebrá-lo em duas linhas, usando \ para pular para a próxima linha
# df_maior_duracao_musica = df.groupby("album")\
# ['duracao_minutos'].mean().sort_values(ascending=False)

df_maior_duracao_musica = df.groupby("album")['duracao_minutos'].mean().sort_values(ascending=False)
df_maior_duracao_musica
# Out:
# album
# Havana Moon (Live)                                                      6.632819
# Bridges To Bremen (Live)                                                6.332265
# Jamming With Edward                                                     6.042794
# Live At The Checkerboard Lounge                                         6.009647
# Totally Stripped - Paris (Live)                                         5.947430
#                                                                           ...
# Out Of Our Heads (UK)                                                   2.464643
# Out Of Our Heads (UK Sequence)                                          2.449274
# December's Children (and everybody's)                                   2.408976
# December’s Children (And Everybody’s)                                   2.408532
# Live 1965: Music From Charlie Is My Darling (Live From England/1965)    2.146082
# Name: duracao_minutos, Length: 90, dtype: float64

# %%
# plotando o top 5 do resultado acima
df_maior_duracao_musica.head(5).plot(kind='bar') # -> dessa forma os títulos ficaram abaixo do eixo X de uma forma ruim para leitura
plt.xlabel("Álbuns")
plt.ylabel("Média de duração das músicas em minutos")

# como alteramos o tipo do gráfico, precisamos ajustar os títulos dos eixos
# df_maior_duracao_musica.head(5).plot(kind='barh')
# plt.ylabel("Álbuns")
# plt.xlabel("Média de duração das músicas em minutos")
plt.title("Top 5 Álbuns com maior duração média de músicas")
plt.show()

# %%
# vamos trabalhar com o gráfico de barras horizontais -> top 10 álbuns com mais músicas
top_albuns = df['album'].value_counts().head(10)

# %%
top_albuns
# Out:
# album
# Voodoo Lounge Uncut (Live)         56
# Honk (Deluxe)                      47
# Live Licks                         46
# Tattoo You (Super Deluxe)          46
# Some Girls (Deluxe Version)        44
# Goats Head Soup (Deluxe)           37
# Flashpoint                         34
# Sticky Fingers (Super Deluxe)      33
# On Air (Deluxe)                    32
# Live At The Checkerboard Lounge    32
# Name: count, dtype: int64

# %%
top_albuns
plt.barh(top_albuns.index, top_albuns.values)
plt.title('Top 10 Álbuns com mais músicas')
plt.show()

# %% [markdown]
# O método between() no Pandas é utilizado para filtrar dados que estão dentro de um intervalo específico. Ele retorna um booleano que indica se os valores estão dentro do intervalo fornecido.
#
# Aqui está a estrutura básica para usá-lo:
#
# DataFrame['coluna'].between(início, fim, inclusive='both')
# Onde:
#
# início é o valor inicial do intervalo.
# fim é o valor final do intervalo.
# inclusive pode ser 'both' (padrão), 'neither', 'left', ou 'right' para definir se os limites do intervalo são inclusivos ou não.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              1610 non-null   object
#  1   album             1610 non-null   object
#  2   release_date      1610 non-null   datetime64[ns]
#  3   track_number      1610 non-null   int64
#  4   acousticness      1610 non-null   float64
#  5   danceability      1610 non-null   float64
#  6   energy            1610 non-null   float64
#  7   instrumentalness  1610 non-null   float64
#  8   liveness          1610 non-null   float64
#  9   loudness          1610 non-null   float64
#  10  speechiness       1610 non-null   float64
#  11  tempo             1610 non-null   float64
#  12  valence           1610 non-null   float64
#  13  popularity        1610 non-null   int64
#  14  duration_ms       1610 non-null   int64
#  15  duracao_minutos   1610 non-null   float64
# ...

# %%
# vamos entender a popularidade da banda na última década - 2011 a 2020 - filtro com between
df_ultima_decada = df[df['release_date'].between(pd.to_datetime('2011'), pd.to_datetime('2020'))]

# %%
df_por_album = df_ultima_decada.groupby('album')['popularity'].sum().sort_values(ascending=False).head(10)

# %%
df_por_album
# Out:
# album
# Honk (Deluxe)                      1232
# Voodoo Lounge Uncut (Live)          654
# On Air (Deluxe)                     573
# Live At The Checkerboard Lounge     482
# Havana Moon (Live)                  445
# Bridges To Buenos Aires (Live)      433
# Blue & Lonesome                     419
# Bridges To Bremen (Live)            396
# Some Girls: Live In Texas '78       344
# Ladies & Gentlemen (Live)           343
# Name: popularity, dtype: int64

# %%
# calculando em porcentagem a popularidade
total_popularidade = df_por_album.sum()

df_porcentagem = df_por_album/total_popularidade * 100

labels = df_porcentagem.index.tolist()
sizes = df_porcentagem.values.tolist()

figura, grafico = plt.subplots(figsize=(18,6))
grafico.pie(sizes, autopct='%1.1f%%') # -> traz a porcentagem com 1 casa decimal - 12,3%. Se quisermos com 2 casas decimais, basta chamar '%1.2f%%'
grafico.axis('equal')
plt.title('Porcentagem de popularidade de álbuns na última década - Top 10')
plt.legend(labels, loc='best')
plt.show()
